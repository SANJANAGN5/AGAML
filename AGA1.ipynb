# %% [markdown]
# WAP to search for a number 9 present in the list[89,14, 21, 34, 55, 3]

# %%
lis = [89,14, 21, 34, 55, 3]
num = 9
if num in lis:
    print(num)
else:
    print("9 is not in the list")
# Out:
# 9 is not in the list

# %% [markdown]
# Find biggest and smallest form the list

# %%
list = [89,14, 21, 34, 55, 3]
highest_elem = max(list)
highest_elem
# Out:
# 89

# %%
list = [89,14, 21, 34, 55, 3]
lowest_elem = min(list)
lowest_elem
# Out:
# 3

# %% [markdown]
# filter the numbers greater than 50

# %%
for i in list:
  if i > 50:
    print(i)
# Out:
# 89
# 55

# %% [markdown]
# count the number of elements in the list [89,14, 21, 34, 55]

# %%
list = [89,14, 21, 34, 55]
length = len(list)
print(length)
# Out:
# 5

# %% [markdown]
# find sum and average of list [89,14, 21, 34, 55]

# %%
sum_of_list = sum(list)
sum_of_list
# Out:
# 213

# %%
average = sum_of_list // len(list)
average
# Out:
# 42

# %%
Hours = float(input("Enter Hours:"))
Rate = float(input("Enter Rate:"))
Pay = Hours * Rate
print("Pay:", Pay)
# Out:
# Enter Hours:35
# Enter Rate:2.75
# Pay: 96.25

# %%
x = 4
if x < 2:
  print('Below 2')
elif x >= 2:
  print('Two or more')
else:
  print('Something else')
# Out:
# Two or more

# %% [markdown]
# we have to declare the 'x' value for above code

# %%
try:
  Hours = float(input("Enter Hours:"))
  Rate = float(input("Enter Rate:"))

  Pay = Hours * Rate
  print("Pay:", Pay)
except:
  print("Error, please enter numeric input")
# Out:
# Enter Hours:35
# Enter Rate:two
# Error, please enter numeric input

# %%
Hours = int(input("Enter Hours:"))
Rate = int(input("Enter Rate:"))

def computepay(Hours, Rate):
    if Hours < 40:
      Pay = Hours * Rate
      print(Pay)
    else:
      Pay = 40 * Rate + (Hours - 40) * Rate * 1.5
      print(Pay)
computepay(Hours, Rate)
# Out:
# Enter Hours:45
# Enter Rate:10
# 475.0
