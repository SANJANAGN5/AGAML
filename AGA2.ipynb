# %%
import scipy
print('scipy: %s' % scipy.__version__)
import numpy
print('numpy: %s' % numpy.__version__)
import pandas
print('pandas: %s' % pandas.__version__)
import matplotlib
print('matplotlib: %s' % matplotlib.__version__)
import sklearn
print('sklearn: %s' % sklearn.__version__)
import statsmodels
print('statsmodels: %s' % statsmodels.__version__)
# Out:
# scipy: 1.16.1
# numpy: 2.0.2
# pandas: 2.2.2
# matplotlib: 3.10.0
# sklearn: 1.6.1
# statsmodels: 0.14.5

# %%
def add_numbers(x,y):
  return x+y

# %%
a = 15; b = 5;
add_numbers(a,b)
# Out:
# 20

# %%
def add_numbers(x, y, z=None):
    if (z == None):
      return x+y
    else:
      return x+y+z

# %%
print(add_numbers(30, 3, 9))
print(add_numbers(30, 3))
# Out:
# 42
# 33

# %%
def add_numbers(x, y, z=None, flag=True):
    if(flag):
      print('Flag is on')
    if (z == None):
      return x+y
    else:
      return x+y+z

print(add_numbers(30, 3, 9))
print(add_numbers(30, 3))
# Out:
# Flag is on
# 42
# Flag is on
# 33

# %%
print(type(None))
# Out:
# <class 'NoneType'>

# %%
print(type('harry'))
# Out:
# <class 'str'>

# %%
print(type(1))
# Out:
# <class 'int'>

# %%
print(type(12.9))
# Out:
# <class 'float'>

# %%
print(type(add_numbers))
# Out:
# <class 'function'>

# %%
print(type(pandas))
# Out:
# <class 'module'>

# %%
x = (1, 'a', 2, 'b', 1.2)
print(type(x))
# Out:
# <class 'tuple'>

# %%
x.append(3.3)
print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1041333650.py in <cell line: 0>()
# ----> 1 x.append(3.3)
#       2 print(x)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
x = [1, 'a', 2, 'b']
type(x)
x.append(3.3)
print(x)
# Out:
# [1, 'a', 2, 'b', 3.3]

# %%
for item in x:
  print(item)
# Out:
# 1
# a
# 2
# b
# 3.3

# %%
i = 0
while( i != len(x)):
  print(x[i])
  i = i+1

# %%
[1,2] + [3,4]
# Out:
# [1, 2, 3, 4]

# %%
(1,2) + (3,4)
# Out:
# (1, 2, 3, 4)

# %%
[10, 1, 3.3] * 3
# Out:
# [10, 1, 3.3, 10, 1, 3.3, 10, 1, 3.3]

# %%
3 in [3,4,5,7,8]
# Out:
# True

# %%
x = 'This is a string'
print(x[0])
print(x[0:1])
print(x[0:2])
print(x[::-1])
print(x[-4:-2])
print(x[:3])
print(x[3:])
# Out:
# T
# T
# Th
# gnirts a si sihT
# ri
# Thi
# s is a string

# %%
first_name = 'Sanjana'
last_name = 'gn'

print(first_name + ' ' + last_name)
print(first_name*3)
print('is' in first_name)
# Out:
# Sanjana gn
# SanjanaSanjanaSanjana
# False

# %%
firstname = 'Tom Mitchell Machine Learning Scientist'.split(' ')[0]
middlename = 'Tom Mitchell Machine Learning Scientist'.split(' ')[1]
lastname = 'Tom Mitchell Machine Learning Scientist'.split(' ')[-1]

print(firstname)
print(middlename)
print(lastname)
# Out:
# Tom
# Mitchell
# Scientist

# %%
'chris' + '2'
# Out:
# 'chris2'

# %%
'chris' + str(2)
# Out:
# 'chris2'

# %%
x = {'Tom': 'tom.m@gmu.org', 'Bill Gates':'bill@microsoft.com'}
x['Bill Gates']
# Out:
# 'bill@microsoft.com'

# %%
x['Thompson'] = 'thm@gmail.com'
print(x)
# Out:
# {'Tom': 'tom.m@gmu.org', 'Bill Gates': 'bill@microsoft.com', 'Thompson': 'thm@gmail.com'}

# %%
for name in x:
  print(x[name]) #values
  print(name)   #keys
# Out:
# tom.m@gmu.org
# Tom
# bill@microsoft.com
# Bill Gates
# thm@gmail.com
# Thompson

# %%
for email in x.values():
  print(email)
# Out:
# tom.m@gmu.org
# bill@microsoft.com
# thm@gmail.com

# %%
for name in x.items():
  print(name)
# Out:
# ('Tom', 'tom.m@gmu.org')
# ('Bill Gates', 'bill@microsoft.com')
# ('Thompson', 'thm@gmail.com')

# %%
x = ('Tom', 'Michel', 'tom@gmail.com')
fname, lname, email = x
lname
# Out:
# 'Michel'

# %%
sales_record = {
    'price': 3.24,
    'num_items': 4,
    'person': 'Tom',
    'email': 'tom@gmail.com'
}
print(sales_record)
# Out:
# {'price': 3.24, 'num_items': 4, 'person': 'Tom', 'email': 'tom@gmail.com'}

# %%
sales_statement = '{} bought {} item(s) at a price opf INR {} each for  a total of INR {}'

# %%
print(sales_statement.format(sales_record['person'],
                             sales_record['num_items'],
                             sales_record['person'],
                             sales_record['email']))
# Out:
# Tom bought 4 item(s) at a price opf INR Tom each for  a total of INR tom@gmail.com

# %%
import datetime as dt
import time as tm
tm.time()
# Out:
# 1755077818.5760107

# %%
from datetime import date
from datetime import time
from datetime import datetime
today = date.today()
print('today date is', today)
# Out:
# today date is 2025-08-13

# %%
delta = dt.timedelta(days = 30)
# Out:
# datetime.timedelta(days=30)

# %%
today = dt.date.today()
today
# Out:
# datetime.date(2025, 8, 13)

# %%
to = today-delta
to
# Out:
# datetime.date(2025, 7, 14)
